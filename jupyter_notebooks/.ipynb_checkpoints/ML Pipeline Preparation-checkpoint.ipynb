# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import nltk
nltk.download(['punkt', 'wordnet', 'stopwords'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# import libraries
import re
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('messages_and_categories', engine)
X = df['message']
y = df.drop(columns=['id', 'message', 'original', 'genre'])

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    text = re.sub(r'\W+', ' ', text)

    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t not in stopwords.words("english")]
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %%
test = X.head()
text_test = X[:1].item()
clean_tokens = tokenize(text_test)
print(clean_tokens)
# Out:
# ['weather', 'update', 'cold', 'front', 'cuba', 'could', 'pas', 'haiti']

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(estimator=RandomForestClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)

# %%
y_labels = list(y_test.columns)
print(y_labels)
# Out:
# ['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']

# %%
for i, label in enumerate(y_labels):
    print(y_labels[i])
    print(classification_report(y_test[label], y_pred[:,i]))
# Out:
# related
#              precision    recall  f1-score   support
#
#           0       0.61      0.45      0.51      1563
#           1       0.84      0.91      0.87      4944
#           2       0.46      0.40      0.43        47
#
# avg / total       0.78      0.79      0.78      6554
#
# request
#              precision    recall  f1-score   support
#
#           0       0.90      0.98      0.93      5443
#           1       0.79      0.44      0.57      1111
#
# avg / total       0.88      0.89      0.87      6554
#
# offer
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6521
#           1       0.00      0.00      0.00        33
#
# avg / total       0.99      0.99      0.99      6554
#
# aid_related
#              precision    recall  f1-score   support
#
#           0       0.76      0.85      0.80      3884
#           1       0.73      0.60      0.66      2670
#
# avg / total       0.75      0.75      0.74      6554
#
# medical_help
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      6019
#           1       0.55      0.10      0.17       535
#
# avg / total       0.89      0.92      0.89      6554
#
# medical_products
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6210
#           1       0.84      0.05      0.09       344
#
# avg / total       0.94      0.95      0.93      6554
#
# search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6395
#           1       0.75      0.04      0.07       159
#
# avg / total       0.97      0.98      0.97      6554
#
# security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6438
#           1       0.25      0.01      0.02       116
#
# avg / total       0.97      0.98      0.97      6554
#
# military
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6354
#           1       0.57      0.08      0.14       200
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6136
#           1       0.85      0.27      0.41       418
#
# avg / total       0.95      0.95      0.94      6554
#
# food
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5809
#           1       0.85      0.47      0.61       745
#
# avg / total       0.93      0.93      0.92      6554
#
# shelter
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5973
#           1       0.81      0.32      0.46       581
#
# avg / total       0.93      0.93      0.92      6554
#
# clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6456
#           1       0.82      0.14      0.24        98
#
# avg / total       0.98      0.99      0.98      6554
#
# money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6421
#           1       1.00      0.06      0.11       133
#
# avg / total       0.98      0.98      0.97      6554
#
# missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6481
#           1       1.00      0.03      0.05        73
#
# avg / total       0.99      0.99      0.98      6554
#
# refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6339
#           1       0.33      0.03      0.05       215
#
# avg / total       0.95      0.97      0.95      6554
#
# death
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6257
#           1       0.69      0.15      0.25       297
#
# avg / total       0.95      0.96      0.95      6554
#
# other_aid
#              precision    recall  f1-score   support
#
#           0       0.87      0.99      0.93      5690
#           1       0.47      0.05      0.08       864
#
# avg / total       0.82      0.87      0.82      6554
#
# infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6143
#           1       0.25      0.00      0.01       411
#
# avg / total       0.89      0.94      0.91      6554
#
# transport
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6251
#           1       0.62      0.07      0.12       303
#
# avg / total       0.94      0.95      0.94      6554
#
# buildings
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6231
#           1       0.71      0.09      0.16       323
#
# avg / total       0.94      0.95      0.94      6554
#
# electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6407
#           1       0.83      0.03      0.07       147
#
# avg / total       0.98      0.98      0.97      6554
#
# tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6511
#           1       0.00      0.00      0.00        43
#
# avg / total       0.99      0.99      0.99      6554
#
# hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6498
#           1       0.00      0.00      0.00        56
#
# avg / total       0.98      0.99      0.99      6554
#
# shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6530
#           1       0.00      0.00      0.00        24
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.00      0.00      0.00        81
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6271
#           1       0.12      0.00      0.01       283
#
# avg / total       0.92      0.96      0.94      6554
#
# weather_related
#              precision    recall  f1-score   support
#
#           0       0.87      0.95      0.91      4781
#           1       0.83      0.62      0.71      1773
#
# avg / total       0.86      0.86      0.85      6554
#
# floods
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6035
#           1       0.85      0.34      0.49       519
#
# avg / total       0.94      0.94      0.93      6554
#
# storm
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.97      5949
#           1       0.75      0.47      0.58       605
#
# avg / total       0.93      0.94      0.93      6554
#
# fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6488
#           1       0.67      0.03      0.06        66
#
# avg / total       0.99      0.99      0.99      6554
#
# earthquake
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      5964
#           1       0.87      0.65      0.74       590
#
# avg / total       0.96      0.96      0.96      6554
#
# cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6413
#           1       0.73      0.08      0.14       141
#
# avg / total       0.97      0.98      0.97      6554
#
# other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6219
#           1       0.53      0.06      0.10       335
#
# avg / total       0.93      0.95      0.93      6554
#
# direct_report
#              precision    recall  f1-score   support
#
#           0       0.85      0.97      0.91      5282
#           1       0.70      0.31      0.43      1272
#
# avg / total       0.82      0.84      0.81      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
print(pipeline.get_params().keys())
# Out:
# dict_keys(['memory', 'steps', 'vect', 'tfidf', 'clf', 'vect__analyzer', 'vect__binary', 'vect__decode_error', 'vect__dtype', 'vect__encoding', 'vect__input', 'vect__lowercase', 'vect__max_df', 'vect__max_features', 'vect__min_df', 'vect__ngram_range', 'vect__preprocessor', 'vect__stop_words', 'vect__strip_accents', 'vect__token_pattern', 'vect__tokenizer', 'vect__vocabulary', 'tfidf__norm', 'tfidf__smooth_idf', 'tfidf__sublinear_tf', 'tfidf__use_idf', 'clf__estimator__bootstrap', 'clf__estimator__class_weight', 'clf__estimator__criterion', 'clf__estimator__max_depth', 'clf__estimator__max_features', 'clf__estimator__max_leaf_nodes', 'clf__estimator__min_impurity_decrease', 'clf__estimator__min_impurity_split', 'clf__estimator__min_samples_leaf', 'clf__estimator__min_samples_split', 'clf__estimator__min_weight_fraction_leaf', 'clf__estimator__n_estimators', 'clf__estimator__n_jobs', 'clf__estimator__oob_score', 'clf__estimator__random_state', 'clf__estimator__verbose', 'clf__estimator__warm_start', 'clf__estimator', 'clf__n_jobs'])

# %%
print(pipeline.get_params())
# Out:
# {'memory': None, 'steps': [('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x7f8b437f99d8>, vocabulary=None)), ('tfidf', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)), ('clf', MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))], 'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x7f8b437f99d8>, vocabulary=None), 'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), 'clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1), 'vect__analyzer': 'word', 'vect__binary': False, 'vect__decode_error': 'strict', 'vect__dtype': <class 'numpy.int64'>, 'vect__encoding': 'utf-8', 'vect__input': 'content', 'vect__lowercase': True, 'vect__max_df': 1.0, 'vect__max_features': None, 'vect__min_df': 1, 'vect__ngram_range': (1, 1), 'vect__preprocessor': None, 'vect__stop_words': None, 'vect__strip_accents': None, 'vect__token_pattern': '(?u)\\b\\w\\w+\\b', 'vect__tokenizer': <function tokenize at 0x7f8b437f99d8>, 'vect__vocabulary': None, 'tfidf__norm': 'l2', 'tfidf__smooth_idf': True, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': True, 'clf__estimator__bootstrap': True, 'clf__estimator__class_weight': None, 'clf__estimator__criterion': 'gini', 'clf__estimator__max_depth': None, 'clf__estimator__max_features': 'auto', 'clf__estimator__max_leaf_nodes': None, 'clf__estimator__min_impurity_decrease': 0.0, 'clf__estimator__min_impurity_split': None, 'clf__estimator__min_samples_leaf': 1, 'clf__estimator__min_samples_split': 2, 'clf__estimator__min_weight_fraction_leaf': 0.0, 'clf__estimator__n_estimators': 10, 'clf__estimator__n_jobs': 1, 'clf__estimator__oob_score': False, 'clf__estimator__random_state': None, 'clf__estimator__verbose': 0, 'clf__estimator__warm_start': False, 'clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False), 'clf__n_jobs': 1}

# %%
    # specify parameters for grid search
    parameters = {
#         'vect__max_df': (0.75, 1.0),
        # 'vect__max_features': (None, 5000, 10000, 50000),
#         'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
        # 'tfidf__use_idf': (True, False),
        # 'tfidf__norm': ('l1', 'l2'),
#         'clf__estimator__bootstrap': [True],
#         'clf__estimator__max_depth': [80, 90, 100, 110],
#         'clf__estimator__max_features': [2, 3],
#         'clf__estimator__min_samples_leaf': [1, 2],
        'clf__estimator__min_samples_split': [2, 3],
        'clf__estimator__n_estimators': [8, 10, 12]
    }

    # create grid search object
    cv = GridSearchCV(pipeline, param_grid=parameters, verbose=72)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, y_train)
y_pred = cv.predict(X_test)
print("Best Parameters:", cv.best_params_)

# for i, label in enumerate(y_labels):
#     print(y_labels[i])
#     print(classification_report(y_test[label], y_pred[:,i]))
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8, score=0.23161428135489778, total= 1.9min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.8min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8, score=0.23863289594140982, total= 1.9min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  5.7min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=8, score=0.2416844675007629, total= 1.9min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  8.5min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, score=0.23680195300579798, total= 2.0min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 11.5min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, score=0.2325297528227037, total= 2.0min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 14.4min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=10, score=0.2462618248397925, total= 2.0min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 17.4min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12, score=0.24595666768385718, total= 2.1min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 20.5min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12, score=0.2416844675007629, total= 2.1min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 23.6min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=12, score=0.24290509612450412, total= 2.1min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 26.7min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8, score=0.22566371681415928, total= 1.8min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 29.5min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8, score=0.2197131522734208, total= 1.8min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 32.2min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=8, score=0.2308513884650595, total= 1.8min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 35.0min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, score=0.22963075984131828, total= 1.9min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 37.9min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, score=0.23207201708880074, total= 1.9min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 40.8min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=10, score=0.2371071101617333, total= 1.9min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 43.7min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12, score=0.23146170277693012, total= 2.0min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 46.7min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12, score=0.2360390601159597, total= 2.0min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 49.8min remaining:    0.0s
# [CV] clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12
# [CV]  clf__estimator__min_samples_split=3, clf__estimator__n_estimators=12, score=0.24641440341776014, total= 2.0min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 52.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 52.8min finished
# Best Parameters: {'clf__estimator__min_samples_split': 2, 'clf__estimator__n_estimators': 12}

# %%
for i, label in enumerate(y_labels):
    print(y_labels[i])
    print(classification_report(y_test[label], y_pred[:,i]))
# Out:
# related
#              precision    recall  f1-score   support
#
#           0       0.65      0.46      0.54      1563
#           1       0.84      0.92      0.88      4944
#           2       0.32      0.32      0.32        47
#
# avg / total       0.79      0.80      0.79      6554
#
# request
#              precision    recall  f1-score   support
#
#           0       0.90      0.98      0.94      5443
#           1       0.80      0.46      0.58      1111
#
# avg / total       0.88      0.89      0.88      6554
#
# offer
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6521
#           1       0.00      0.00      0.00        33
#
# avg / total       0.99      0.99      0.99      6554
#
# aid_related
#              precision    recall  f1-score   support
#
#           0       0.77      0.85      0.80      3884
#           1       0.74      0.62      0.68      2670
#
# avg / total       0.75      0.76      0.75      6554
#
# medical_help
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      6019
#           1       0.70      0.15      0.25       535
#
# avg / total       0.91      0.93      0.90      6554
#
# medical_products
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6210
#           1       0.62      0.09      0.16       344
#
# avg / total       0.93      0.95      0.93      6554
#
# search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6395
#           1       0.50      0.03      0.05       159
#
# avg / total       0.96      0.98      0.96      6554
#
# security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6438
#           1       0.20      0.01      0.02       116
#
# avg / total       0.97      0.98      0.97      6554
#
# military
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6354
#           1       0.58      0.09      0.16       200
#
# avg / total       0.96      0.97      0.96      6554
#
# child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6136
#           1       0.84      0.30      0.44       418
#
# avg / total       0.95      0.95      0.94      6554
#
# food
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5809
#           1       0.87      0.43      0.57       745
#
# avg / total       0.92      0.93      0.92      6554
#
# shelter
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5973
#           1       0.78      0.30      0.43       581
#
# avg / total       0.92      0.93      0.92      6554
#
# clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6456
#           1       0.60      0.09      0.16        98
#
# avg / total       0.98      0.99      0.98      6554
#
# money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6421
#           1       0.71      0.08      0.14       133
#
# avg / total       0.98      0.98      0.97      6554
#
# missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6481
#           1       1.00      0.01      0.03        73
#
# avg / total       0.99      0.99      0.98      6554
#
# refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6339
#           1       0.25      0.01      0.03       215
#
# avg / total       0.94      0.97      0.95      6554
#
# death
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6257
#           1       0.76      0.17      0.28       297
#
# avg / total       0.95      0.96      0.95      6554
#
# other_aid
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5690
#           1       0.55      0.04      0.07       864
#
# avg / total       0.83      0.87      0.82      6554
#
# infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6143
#           1       0.33      0.00      0.01       411
#
# avg / total       0.90      0.94      0.91      6554
#
# transport
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6251
#           1       0.71      0.12      0.20       303
#
# avg / total       0.95      0.96      0.94      6554
#
# buildings
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6231
#           1       0.85      0.09      0.16       323
#
# avg / total       0.95      0.95      0.94      6554
#
# electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6407
#           1       1.00      0.04      0.08       147
#
# avg / total       0.98      0.98      0.97      6554
#
# tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6511
#           1       0.00      0.00      0.00        43
#
# avg / total       0.99      0.99      0.99      6554
#
# hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6498
#           1       0.00      0.00      0.00        56
#
# avg / total       0.98      0.99      0.99      6554
#
# shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6530
#           1       0.00      0.00      0.00        24
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.00      0.00      0.00        81
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6271
#           1       0.00      0.00      0.00       283
#
# avg / total       0.92      0.96      0.94      6554
#
# weather_related
#              precision    recall  f1-score   support
#
#           0       0.88      0.95      0.92      4781
#           1       0.83      0.66      0.74      1773
#
# avg / total       0.87      0.87      0.87      6554
#
# floods
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6035
#           1       0.83      0.38      0.52       519
#
# avg / total       0.94      0.94      0.93      6554
#
# storm
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      5949
#           1       0.77      0.43      0.55       605
#
# avg / total       0.93      0.94      0.93      6554
#
# fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6488
#           1       0.50      0.03      0.06        66
#
# avg / total       0.99      0.99      0.99      6554
#
# earthquake
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5964
#           1       0.90      0.75      0.82       590
#
# avg / total       0.97      0.97      0.97      6554
#
# cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6413
#           1       0.86      0.09      0.15       141
#
# avg / total       0.98      0.98      0.97      6554
#
# other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6219
#           1       0.59      0.05      0.09       335
#
# avg / total       0.93      0.95      0.93      6554
#
# direct_report
#              precision    recall  f1-score   support
#
#           0       0.85      0.97      0.91      5282
#           1       0.73      0.31      0.43      1272
#
# avg / total       0.83      0.84      0.82      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(estimator=AdaBoostClassifier()))
    ])
print(pipeline.get_params())
# Out:
# {'memory': None, 'steps': [('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x7f87ca6997b8>, vocabulary=None)), ('tfidf', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)), ('clf', MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=1))], 'vect': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function tokenize at 0x7f87ca6997b8>, vocabulary=None), 'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), 'clf': MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=1), 'vect__analyzer': 'word', 'vect__binary': False, 'vect__decode_error': 'strict', 'vect__dtype': <class 'numpy.int64'>, 'vect__encoding': 'utf-8', 'vect__input': 'content', 'vect__lowercase': True, 'vect__max_df': 1.0, 'vect__max_features': None, 'vect__min_df': 1, 'vect__ngram_range': (1, 1), 'vect__preprocessor': None, 'vect__stop_words': None, 'vect__strip_accents': None, 'vect__token_pattern': '(?u)\\b\\w\\w+\\b', 'vect__tokenizer': <function tokenize at 0x7f87ca6997b8>, 'vect__vocabulary': None, 'tfidf__norm': 'l2', 'tfidf__smooth_idf': True, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': True, 'clf__estimator__algorithm': 'SAMME.R', 'clf__estimator__base_estimator': None, 'clf__estimator__learning_rate': 1.0, 'clf__estimator__n_estimators': 50, 'clf__estimator__random_state': None, 'clf__estimator': AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None), 'clf__n_jobs': 1}

# %%
# specify parameters for grid search
parameters = {
#         'vect__max_df': (0.75, 1.0),
    # 'vect__max_features': (None, 5000, 10000, 50000),
#         'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    # 'tfidf__use_idf': (True, False),
    # 'tfidf__norm': ('l1', 'l2'),
#         'clf__estimator__bootstrap': [True],
#         'clf__estimator__max_depth': [80, 90, 100, 110],
#         'clf__estimator__max_features': [2, 3],
#         'clf__estimator__min_samples_leaf': [1, 2],
    'clf__estimator__learning_rate': [0.1, 0.5],
    'clf__estimator__n_estimators': [50, 60, 70]
}

# create grid search object
cv = GridSearchCV(pipeline, param_grid=parameters, verbose=72)

# %%
cv.fit(X_train, y_train)
y_pred = cv.predict(X_test)
print("Best Parameters:", cv.best_params_)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50, score=0.2036924015868172, total= 2.4min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.4min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50, score=0.20201403722917302, total= 2.4min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  6.9min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=50, score=0.2119316447970705, total= 2.4min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 10.3min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60, score=0.19804699420201405, total= 2.7min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 14.0min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60, score=0.20674397314617027, total= 2.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 17.7min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=60, score=0.2090326518156851, total= 2.7min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 21.4min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70, score=0.2007934086054318, total= 2.9min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 25.4min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70, score=0.20750686603600854, total= 2.9min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 29.3min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=70, score=0.21071101617332927, total= 3.0min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 33.3min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50, score=0.21833994507171192, total= 2.5min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 36.8min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50, score=0.2322245956667684, total= 2.5min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 40.2min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=50, score=0.23207201708880074, total= 2.5min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 43.7min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60, score=0.2168141592920354, total= 2.7min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 47.4min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60, score=0.22871528837351235, total= 2.7min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 51.1min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=60, score=0.23039365273115656, total= 2.7min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 54.8min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70, score=0.2181873664937443, total= 2.9min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 58.7min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70, score=0.23130912419896246, total= 2.9min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 62.6min remaining:    0.0s
# [CV] clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70
# [CV]  clf__estimator__learning_rate=0.5, clf__estimator__n_estimators=70, score=0.2302410741531889, total= 2.9min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 66.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 66.6min finished
# Best Parameters: {'clf__estimator__learning_rate': 0.5, 'clf__estimator__n_estimators': 50}

# %%
y_labels = list(y_test.columns)
print(y_labels)
for i, label in enumerate(y_labels):
    print(y_labels[i])
    print(classification_report(y_test[label], y_pred[:,i]))
# Out:
# ['related', 'request', 'offer', 'aid_related', 'medical_help', 'medical_products', 'search_and_rescue', 'security', 'military', 'child_alone', 'water', 'food', 'shelter', 'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid', 'infrastructure_related', 'transport', 'buildings', 'electricity', 'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure', 'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather', 'direct_report']
# related
#              precision    recall  f1-score   support
#
#           0       0.81      0.05      0.09      1563
#           1       0.76      1.00      0.86      4944
#           2       1.00      0.04      0.08        47
#
# avg / total       0.78      0.76      0.67      6554
#
# request
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94      5443
#           1       0.82      0.43      0.56      1111
#
# avg / total       0.88      0.89      0.87      6554
#
# offer
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6521
#           1       0.00      0.00      0.00        33
#
# avg / total       0.99      0.99      0.99      6554
#
# aid_related
#              precision    recall  f1-score   support
#
#           0       0.74      0.89      0.81      3884
#           1       0.78      0.54      0.64      2670
#
# avg / total       0.76      0.75      0.74      6554
#
# medical_help
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      6019
#           1       0.59      0.14      0.22       535
#
# avg / total       0.90      0.92      0.90      6554
#
# medical_products
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6210
#           1       0.81      0.22      0.35       344
#
# avg / total       0.95      0.96      0.94      6554
#
# search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6395
#           1       0.74      0.11      0.19       159
#
# avg / total       0.97      0.98      0.97      6554
#
# security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6438
#           1       0.00      0.00      0.00       116
#
# avg / total       0.96      0.98      0.97      6554
#
# military
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6354
#           1       0.67      0.20      0.30       200
#
# avg / total       0.97      0.97      0.97      6554
#
# child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# water
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6136
#           1       0.77      0.62      0.69       418
#
# avg / total       0.96      0.96      0.96      6554
#
# food
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5809
#           1       0.82      0.72      0.77       745
#
# avg / total       0.95      0.95      0.95      6554
#
# shelter
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5973
#           1       0.81      0.49      0.61       581
#
# avg / total       0.94      0.95      0.94      6554
#
# clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6456
#           1       0.81      0.26      0.39        98
#
# avg / total       0.99      0.99      0.98      6554
#
# money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6421
#           1       0.50      0.17      0.26       133
#
# avg / total       0.97      0.98      0.97      6554
#
# missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6481
#           1       0.78      0.10      0.17        73
#
# avg / total       0.99      0.99      0.99      6554
#
# refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6339
#           1       0.59      0.17      0.27       215
#
# avg / total       0.96      0.97      0.96      6554
#
# death
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6257
#           1       0.84      0.36      0.50       297
#
# avg / total       0.96      0.97      0.96      6554
#
# other_aid
#              precision    recall  f1-score   support
#
#           0       0.88      0.99      0.93      5690
#           1       0.60      0.07      0.12       864
#
# avg / total       0.84      0.87      0.82      6554
#
# infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6143
#           1       0.59      0.04      0.07       411
#
# avg / total       0.92      0.94      0.91      6554
#
# transport
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6251
#           1       0.76      0.14      0.23       303
#
# avg / total       0.95      0.96      0.94      6554
#
# buildings
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6231
#           1       0.82      0.27      0.40       323
#
# avg / total       0.96      0.96      0.95      6554
#
# electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6407
#           1       0.67      0.11      0.19       147
#
# avg / total       0.97      0.98      0.97      6554
#
# tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6511
#           1       0.00      0.00      0.00        43
#
# avg / total       0.99      0.99      0.99      6554
#
# hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6498
#           1       0.29      0.04      0.06        56
#
# avg / total       0.99      0.99      0.99      6554
#
# shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6530
#           1       0.00      0.00      0.00        24
#
# avg / total       0.99      1.00      0.99      6554
#
# aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.40      0.02      0.05        81
#
# avg / total       0.98      0.99      0.98      6554
#
# other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6271
#           1       0.33      0.01      0.03       283
#
# avg / total       0.93      0.96      0.94      6554
#
# weather_related
#              precision    recall  f1-score   support
#
#           0       0.86      0.97      0.91      4781
#           1       0.87      0.59      0.70      1773
#
# avg / total       0.87      0.87      0.86      6554
#
# floods
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6035
#           1       0.88      0.56      0.69       519
#
# avg / total       0.96      0.96      0.96      6554
#
# storm
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96      5949
#           1       0.72      0.45      0.56       605
#
# avg / total       0.93      0.93      0.93      6554
#
# fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6488
#           1       0.91      0.15      0.26        66
#
# avg / total       0.99      0.99      0.99      6554
#
# earthquake
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5964
#           1       0.89      0.79      0.84       590
#
# avg / total       0.97      0.97      0.97      6554
#
# cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6413
#           1       0.77      0.26      0.39       141
#
# avg / total       0.98      0.98      0.98      6554
#
# other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6219
#           1       0.50      0.06      0.11       335
#
# avg / total       0.93      0.95      0.93      6554
#
# direct_report
#              precision    recall  f1-score   support
#
#           0       0.85      0.98      0.91      5282
#           1       0.76      0.29      0.42      1272
#
# avg / total       0.83      0.84      0.82      6554

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle
# Export the classifier to a file
with open('model.pkl', 'wb') as model_file:
  pickle.dump(pipeline, model_file)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
